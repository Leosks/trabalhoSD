# %% [markdown]
# ***Etapa 1 - Web Scraping***

# %% [markdown]
# Importando as Bibliotecas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tqdm import tqdm
import string
import sys
from urllib.request import urlopen
import nltk
from bs4 import BeautifulSoup
import os

# %% [markdown]
# URL alvo para Web Scrapping

# %%
url = 'https://www.letras.mus.br/'

# %% [markdown]
# Coleta dos Links de letras de músicas de uma banda

# %%
  def get_lyrics(band):
    try:
      print('Obtendo links/músicas')
      #Listas com valores únicos
      ctrl_page = set()

      #https://www.letras.mus.br/luan-santana
      #https://www.letras.mus.br/henrique-e-juliano
      #https://www.letras.mus.br/mc-kevinho
      #https://www.letras.mus.br/mc-maha/
      #https://www.letras.mus.br/metallica
      #https://www.letras.mus.br/nirvana/
      html = urlopen(f"{url}/{band}")

      #Parser das Tags HTML
      bs = BeautifulSoup(html, 'html.parser')

      #Neste momento estamos filtrando as tags do tipo <a> que estão contidas na tag <ol> da página
      for link in bs.find('ol', {'class': 'cnt-list cnt-list--num -flex-col-2 js-song-list'}).find_all('a'):
            if 'href' in link.attrs:
                #Adicionando as páginas que contém a letra de música em uma lista
                ctrl_page.add(f"{link.attrs['href']}")
        
      for lyrics in ctrl_page:
            #Chamar Função pra ler a sub-página que contém as letras completas, além do nome da música
            get_music(band,lyrics)
            
    except Exception as e:
        print(f'Ocorreu algum erro ao tentar acessar o site. {e}')

# %%
def get_lyrics(band):
    try:
        print('Obtendo links/músicas')
        #Lista, com valores únicos
        ctrl_page = set()
        
        #https://www.letras.mus.br/luan-santana
        #https://www.letras.mus.br/henrique-e-juliano
        #https://www.letras.mus.br/mc-kevinho
        #https://www.letras.mus.br/mc-maha/
        #https://www.letras.mus.br/metallica
        #https://www.letras.mus.br/nirvana/
        html = urlopen(f"{url}/{band}")
        
        #Parser das tags HTML
        bs = BeautifulSoup(html, 'html.parser')
        
        #Neste momento estamos filtrando as tags do tipo <a> que estão contidas na tag <ol> da página
        for link in bs.find('ol', {'class': 'cnt-list cnt-list--num -flex-col-2 js-song-list'}).find_all('a'):
            if 'href' in link.attrs:
                #Adicionando as páginas que contém a letra de música em uma lista
                ctrl_page.add(f"{link.attrs['href']}")
        
        for lyrics in ctrl_page:
            #Chamar Função pra ler a sub-página que contém as letras completas, além do nome da música
            get_music(band,lyrics)
            
    except Exception as e:
        print(f'Ocorreu algum erro ao tentar acessar o site. {e}')

# %% [markdown]
# Captura Todas as Músicas de uma Banda
#
# Captura todas as músicas de uma banda, grupo ou artista a partir da página www.letras.com.br/[banda/nome_da_música].

# %%
  def get_music(band, new_page):
    music = ''
    print(band)
    try:
        #lendo as letras completas
        html = urlopen(f"{url}/{new_page}")
        #parser novamente com a página html lida
        bs = BeautifulSoup(html, 'html.parser')
        
        #Estamos lendo os versos que estão separados por tags <p>
        #posteriormente nós limpamos e agrupamos a letra.
        for verse in tqdm(bs.find('div', {'class': 'cnt-letra p402_premium'}).find_all('p')):
            music += ' '.join(verse.stripped_strings)
            music += ' '
            
        
        #coleta do título da música na tag <div> com a class 'cnt-head_title'
        title_music = bs.find('div', {'class': 'cnt-head_title'}).find_all('h1')[0]
        title_music = ' '.join(title_music.stripped_strings) 
            
        #Salvando estas informações
        save_lyrics(band, music, title_music)
        
        print("Letra Capturada : " + title_music)   
    except Exception as e:
        print(f'Ocorreu algum erro ao tentar acessar o site. {e}')

# %% [markdown]
# Salva letra da Música em Disco
#
# Salva a letra de música em disco no formato .txt contando o padrão '**band$title_music**.txt'

# %%
  def save_lyrics(band, music, title_music):

    plain_text = music.lower()

    try:
      print(plain_text, file=open(f'/content/drive/My Drive/TrabalhoSD/data/{band}${title_music}.txt', 'w'))

    except Exception as e:
      print(f'Ocorreu algum erro ao tentar gravar o arquivo. {e}')

# %% [markdown]
# Capturando Letras de Músicas

# %%
  get_lyrics("luan-santana")
  get_lyrics("henrique-e-juliano")
  get_lyrics("mc-kevinho")
  get_lyrics("mc-maha")
  get_lyrics("metallica")
  get_lyrics("nirvana")
# Out:
# Obtendo links/músicas
# 100%|██████████| 7/7 [00:00<00:00, 7924.46it/s]
# luan-santana
# Letra Capturada : Asas
# luan-santana
# 100%|██████████| 13/13 [00:00<00:00, 14405.80it/s]
# 100%|██████████| 8/8 [00:00<00:00, 5904.35it/s]
# Letra Capturada : Mesmo Sem Estar (part. Sandy)
# luan-santana
# Letra Capturada : Vingança (part. MC Kekel)
# luan-santana
# 100%|██████████| 8/8 [00:00<00:00, 7683.63it/s]
# 100%|██████████| 10/10 [00:00<00:00, 3289.13it/s]
# Letra Capturada : Tudo Que Você Quiser
# luan-santana
# 100%|██████████| 7/7 [00:00<00:00, 4924.54it/s]
# Letra Capturada : Quando a Bad Bater
# luan-santana
# Letra Capturada : Boa Memória
# luan-santana
# 100%|██████████| 8/8 [00:00<00:00, 5891.91it/s]
# 100%|██████████| 10/10 [00:00<00:00, 3268.12it/s]
# Letra Capturada : Garotas Não Merecem Chorar
# luan-santana
# Letra Capturada : Amar Não É Pecado
# luan-santana
# 100%|██████████| 7/7 [00:00<00:00, 6501.36it/s]
# 100%|██████████| 9/9 [00:00<00:00, 3250.56it/s]
# Letra Capturada : Incondicional
# luan-santana
# Letra Capturada : Chuva de Arroz
# luan-santana
# 100%|██████████| 9/9 [00:00<00:00, 11712.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 12671.61it/s]
# Letra Capturada : Água Com Açúcar
# luan-santana
# Letra Capturada : Te Esperando
# luan-santana
# 100%|██████████| 10/10 [00:00<00:00, 8203.22it/s]
# 100%|██████████| 9/9 [00:00<00:00, 31562.49it/s]
# Letra Capturada : Meteoro
# luan-santana
# Letra Capturada : Dia, Lugar e Hora
# luan-santana
# 100%|██████████| 10/10 [00:00<00:00, 3175.10it/s]
# 100%|██████████| 14/14 [00:00<00:00, 15891.81it/s]
# Letra Capturada : Eu, Você, o Mar e Ela
# luan-santana
# Letra Capturada : Acordando o Prédio
# luan-santana
# 100%|██████████| 13/13 [00:00<00:00, 34663.67it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1271.29it/s]
# Letra Capturada : A
# luan-santana
# Letra Capturada : Choque Térmico
# luan-santana
# 100%|██████████| 5/5 [00:00<00:00, 1578.71it/s]
# 100%|██████████| 7/7 [00:00<00:00, 2658.95it/s]
# Letra Capturada : Escreve Aí
# luan-santana
# Letra Capturada : Te Vivo
# Obtendo links/músicas
# 100%|██████████| 11/11 [00:00<00:00, 21499.23it/s]
# henrique-e-juliano
# Letra Capturada : Online
# henrique-e-juliano
# 100%|██████████| 10/10 [00:00<00:00, 4333.41it/s]
# 100%|██████████| 8/8 [00:00<00:00, 9595.21it/s]
# Letra Capturada : Não Gosto Eu Amo
# henrique-e-juliano
# Letra Capturada : Briga Feia
# henrique-e-juliano
# 100%|██████████| 5/5 [00:00<00:00, 4687.42it/s]
# 100%|██████████| 15/15 [00:00<00:00, 17133.59it/s]
# Letra Capturada : Recaídas
# henrique-e-juliano
# Letra Capturada : Liberdade Provisória
# henrique-e-juliano
# 100%|██████████| 10/10 [00:00<00:00, 16163.02it/s]
# 100%|██████████| 4/4 [00:00<00:00, 3501.82it/s]
# Letra Capturada : Amor Atual
# henrique-e-juliano
# Letra Capturada : Obrigado Deus
# henrique-e-juliano
# 100%|██████████| 7/7 [00:00<00:00, 8146.54it/s]
# 100%|██████████| 9/9 [00:00<00:00, 10803.87it/s]
# Letra Capturada : O Céu Explica Tudo
# henrique-e-juliano
# Letra Capturada : Se Eu Fosse Você
# henrique-e-juliano
# 100%|██████████| 10/10 [00:00<00:00, 9920.30it/s]
# 100%|██████████| 5/5 [00:00<00:00, 5356.71it/s]
# Letra Capturada : Aquela Pessoa
# henrique-e-juliano
# Letra Capturada : Até Você Voltar
# henrique-e-juliano
# 100%|██████████| 7/7 [00:00<00:00, 23081.86it/s]
# 100%|██████████| 9/9 [00:00<00:00, 7724.32it/s]
# Letra Capturada : Alô Bebê
# henrique-e-juliano
# Letra Capturada : Flor e o Beija-flor (part. Marília Mendonça)
# henrique-e-juliano
# 100%|██████████| 5/5 [00:00<00:00, 3023.58it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12909.52it/s]
# Letra Capturada : Mudando de Assunto
# henrique-e-juliano
# Letra Capturada : Sem Rede
# henrique-e-juliano
# 100%|██████████| 9/9 [00:00<00:00, 31457.28it/s]
# 100%|██████████| 7/7 [00:00<00:00, 7303.51it/s]
# Letra Capturada : Vem Pra Minha Vida
# henrique-e-juliano
# Letra Capturada : Cidade Vizinha
# henrique-e-juliano
# 100%|██████████| 4/4 [00:00<00:00, 4340.81it/s]
# 100%|██████████| 9/9 [00:00<00:00, 6194.41it/s]
# Letra Capturada : Na Hora da Raiva
# henrique-e-juliano
# Letra Capturada : Volta Por Baixo
# henrique-e-juliano
# 100%|██████████| 5/5 [00:00<00:00, 1737.35it/s]
# Letra Capturada : Cuida Bem Dela
# Obtendo links/músicas
# 100%|██████████| 4/4 [00:00<00:00, 1172.58it/s]
# mc-kevinho
# Letra Capturada : O Grave Bater
# mc-kevinho
# 100%|██████████| 7/7 [00:00<00:00, 5382.24it/s]
# 100%|██████████| 11/11 [00:00<00:00, 4931.84it/s]
# Letra Capturada : Se Ferrou (part. Dennis)
# mc-kevinho
# Letra Capturada : Agora É Tudo Meu (part. Dennis DJ)
# mc-kevinho
# 100%|██████████| 13/13 [00:00<00:00, 8088.70it/s]
# 100%|██████████| 8/8 [00:00<00:00, 24456.58it/s]
# Letra Capturada : O Bebê (part. MC Kekel)
# mc-kevinho
# Letra Capturada : Avançada
# mc-kevinho
# 100%|██████████| 14/14 [00:00<00:00, 14802.18it/s]
# 100%|██████████| 11/11 [00:00<00:00, 14301.72it/s]
# Letra Capturada : Eterna Sacanagem (part. MC Jottapê e MC Kekel)
# mc-kevinho
# Letra Capturada : PaPum
# mc-kevinho
# 100%|██████████| 5/5 [00:00<00:00, 3960.63it/s]
# 100%|██████████| 13/13 [00:00<00:00, 15074.91it/s]
# Letra Capturada : Facilita
# mc-kevinho
# Letra Capturada : Rabiola
# mc-kevinho
# 100%|██████████| 5/5 [00:00<00:00, 6458.74it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12063.00it/s]
# Letra Capturada : Uma Nora Pra Cada Dia
# mc-kevinho
# Letra Capturada : Olha a Explosão
# mc-kevinho
# 100%|██████████| 11/11 [00:00<00:00, 13629.94it/s]
# 100%|██████████| 14/14 [00:00<00:00, 6246.84it/s]
# Letra Capturada : Salvou Meu Dia (part. Gusttavo Lima)
# mc-kevinho
# Letra Capturada : Paredão (part. Dadá Boladão e MC JottaPê)
# mc-kevinho
# 100%|██████████| 11/11 [00:00<00:00, 3944.71it/s]
# 100%|██████████| 3/3 [00:00<00:00, 3696.51it/s]
# Letra Capturada : Olha a Explosão (part. Wesley Safadão)
# mc-kevinho
# Letra Capturada : Credo, Que Delícia
# mc-kevinho
# 100%|██████████| 11/11 [00:00<00:00, 8434.61it/s]
# 100%|██████████| 9/9 [00:00<00:00, 11194.76it/s]
# Letra Capturada : Ta Tum Tum (part. Simone & Simaria)
# mc-kevinho
# Letra Capturada : Corpo Sensual (feat. Tyga)
# mc-kevinho
# 100%|██████████| 11/11 [00:00<00:00, 3203.76it/s]
# 100%|██████████| 4/4 [00:00<00:00, 2295.73it/s]
# Letra Capturada : Te Gusta
# mc-kevinho
# Letra Capturada : Tumbalatum
# mc-kevinho
# 100%|██████████| 13/13 [00:00<00:00, 5003.30it/s]
# Letra Capturada : Tô Apaixonado Nessa Mina
# Obtendo links/músicas
# mc-maha
# 100%|██████████| 17/17 [00:00<00:00, 14074.85it/s]
# 100%|██████████| 7/7 [00:00<00:00, 5582.83it/s]
# Letra Capturada : Mamatsu no Papai
# mc-maha
# Letra Capturada : Sem Compromisso
# mc-maha
# 100%|██████████| 6/6 [00:00<00:00, 3647.75it/s]
# 100%|██████████| 9/9 [00:00<00:00, 7823.57it/s]
# Letra Capturada : Harry Porra e a Bruxinha Rabuda (versão explícita)
# mc-maha
# Letra Capturada : Auxilio Emergencial
# mc-maha
# 100%|██████████| 13/13 [00:00<00:00, 14841.03it/s]
# 100%|██████████| 15/15 [00:00<00:00, 3484.03it/s]
# Letra Capturada : Senhor Dos Anais
# mc-maha
# Letra Capturada : One Pinto
# mc-maha
# 100%|██████████| 11/11 [00:00<00:00, 11540.11it/s]
# 100%|██████████| 10/10 [00:00<00:00, 9041.40it/s]
# Letra Capturada : Attack On Tcheca
# mc-maha
# Letra Capturada : Funk Emo
# mc-maha
# 100%|██████████| 7/7 [00:00<00:00, 4596.86it/s]
# 100%|██████████| 5/5 [00:00<00:00, 2015.33it/s]
# Letra Capturada : Guerra Infinita
# mc-maha
# Letra Capturada : Boku No Piru
# mc-maha
# 100%|██████████| 3/3 [00:00<00:00, 1135.64it/s]
# 100%|██████████| 12/12 [00:00<00:00, 16459.01it/s]
# Letra Capturada : Kurapika
# mc-maha
# Letra Capturada : KonohaTron
# 100%|██████████| 4/4 [00:00<00:00, 2514.19it/s]
# mc-maha
# Letra Capturada : Harry P*rra e a Ordem do Pênix
# mc-maha
# 100%|██████████| 7/7 [00:00<00:00, 3116.79it/s]
# 100%|██████████| 11/11 [00:00<00:00, 12901.94it/s]
# Letra Capturada : Vou Entrar no BTS
# mc-maha
# Letra Capturada : Funk da Bettina
# mc-maha
# 100%|██████████| 11/11 [00:00<00:00, 31973.21it/s]
# 100%|██████████| 6/6 [00:00<00:00, 6840.40it/s]
# Letra Capturada : Sexo Casual
# mc-maha
# Letra Capturada : Treta Nas Estrelas
# mc-maha
# 100%|██████████| 9/9 [00:00<00:00, 12839.71it/s]
# 100%|██████████| 5/5 [00:00<00:00, 6094.60it/s]
# Letra Capturada : Eu Kimetsu No Seu Rayba
# mc-maha
# Letra Capturada : Dê Uma Sentada Pro Seu Bruxo - Funk The Witcher
# mc-maha
# 100%|██████████| 3/3 [00:00<00:00, 3563.55it/s]
# Letra Capturada : Akatsoka
# Obtendo links/músicas
# 100%|██████████| 4/4 [00:00<00:00, 5477.38it/s]
# metallica
# Letra Capturada : For Whom The Bell Tolls
# metallica
# 100%|██████████| 8/8 [00:00<00:00, 5419.00it/s]
# 100%|██████████| 13/13 [00:00<00:00, 13881.35it/s]
# Letra Capturada : Creeping Death
# metallica
# Letra Capturada : The Unforgiven II
# metallica
# 100%|██████████| 9/9 [00:00<00:00, 7841.45it/s]
# 100%|██████████| 9/9 [00:00<00:00, 5013.11it/s]
# Letra Capturada : Whiskey In The Jar
# metallica
# Letra Capturada : Mama Said
# metallica
# 100%|██████████| 10/10 [00:00<00:00, 15557.51it/s]
# 100%|██████████| 10/10 [00:00<00:00, 8649.83it/s]
# Letra Capturada : Nothing Else Matters
# metallica
# Letra Capturada : ...And Justice For All
# metallica
# 100%|██████████| 10/10 [00:00<00:00, 12150.36it/s]
# 100%|██████████| 14/14 [00:00<00:00, 4143.11it/s]
# Letra Capturada : Turn The Page
# metallica
# Letra Capturada : Wherever I May Roam
# metallica
# 100%|██████████| 9/9 [00:00<00:00, 7057.16it/s]
# 100%|██████████| 13/13 [00:00<00:00, 15016.79it/s]
# Letra Capturada : One
# metallica
# Letra Capturada : Don't Tread On Me
# metallica
# 100%|██████████| 13/13 [00:00<00:00, 14889.66it/s]
# 100%|██████████| 18/18 [00:00<00:00, 11442.48it/s]
# Letra Capturada : Master Of Puppets
# metallica
# Letra Capturada : Fuel
# metallica
# 100%|██████████| 13/13 [00:00<00:00, 18991.97it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1257.76it/s]
# Letra Capturada : The Unforgiven III
# metallica
# Letra Capturada : Fade To Black
# metallica
# 100%|██████████| 7/7 [00:00<00:00, 18056.66it/s]
# 100%|██████████| 8/8 [00:00<00:00, 21116.70it/s]
# Letra Capturada : Enter Sandman
# metallica
# Letra Capturada : The Day That Never Comes
# metallica
# 100%|██████████| 12/12 [00:00<00:00, 12483.05it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12150.36it/s]
# Letra Capturada : The Unforgiven
# metallica
# Letra Capturada : Seek & Destroy
# metallica
# 100%|██████████| 12/12 [00:00<00:00, 4018.17it/s]
# Letra Capturada : Sad But True
# Obtendo links/músicas
# 100%|██████████| 10/10 [00:00<00:00, 10626.56it/s]
# nirvana
# Letra Capturada : Rape Me
# 100%|██████████| 11/11 [00:00<00:00, 22874.24it/s]
# nirvana
# Letra Capturada : Breed
# nirvana
# 100%|██████████| 7/7 [00:00<00:00, 2168.56it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12503.72it/s]
# Letra Capturada : Polly
# nirvana
# Letra Capturada : Come As You Are
# nirvana
# 100%|██████████| 6/6 [00:00<00:00, 4204.11it/s]
# 100%|██████████| 7/7 [00:00<00:00, 8992.38it/s]
# Letra Capturada : Heart-Shaped Box
# nirvana
# Letra Capturada : About a Girl
# nirvana
# 100%|██████████| 4/4 [00:00<00:00, 1757.14it/s]
# 100%|██████████| 11/11 [00:00<00:00, 12598.95it/s]
# Letra Capturada : Something In The Way
# nirvana
# Letra Capturada : You Know You're Right
# nirvana
# 100%|██████████| 9/9 [00:00<00:00, 11759.73it/s]
# 100%|██████████| 5/5 [00:00<00:00, 5629.94it/s]
# Letra Capturada : Smells Like Teen Spirit
# nirvana
# Letra Capturada : Dumb
# nirvana
# 100%|██████████| 9/9 [00:00<00:00, 3134.76it/s]
# 100%|██████████| 3/3 [00:00<00:00, 3794.61it/s]
# Letra Capturada : Where Did You Sleep Last Night
# nirvana
# Letra Capturada : Jesus Doesn't Want Me For A Sunbeam
# nirvana
# 100%|██████████| 14/14 [00:00<00:00, 5214.02it/s]
# 100%|██████████| 8/8 [00:00<00:00, 8460.52it/s]
# Letra Capturada : Lithium
# nirvana
# Letra Capturada : All Apologies
# nirvana
# 100%|██████████| 8/8 [00:00<00:00, 3806.95it/s]
# 100%|██████████| 6/6 [00:00<00:00, 5387.67it/s]
# Letra Capturada : In Bloom
# nirvana
# 100%|██████████| 8/8 [00:00<00:00, 9900.98it/s]
# Letra Capturada : Lounge Act
# nirvana
# Letra Capturada : Territorial Pissings
# nirvana
# 100%|██████████| 6/6 [00:00<00:00, 6777.76it/s]
# 100%|██████████| 7/7 [00:00<00:00, 8043.87it/s]
# Letra Capturada : Pennyroyal Tea
# nirvana
# Letra Capturada : The Man Who Sold The World
# nirvana
# 100%|██████████| 7/7 [00:00<00:00, 7920.19it/s]
# Letra Capturada : Drain You
