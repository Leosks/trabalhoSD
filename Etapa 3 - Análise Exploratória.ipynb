# %% [markdown]
# Etapa 3 - Análise Exploratória

# %% [markdown]
# Importar Bibliotecas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import plotly.graph_objects as go

from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from tqdm import tqdm

# %% [markdown]
# Leitura do DataSet

# %%
df_lyrics = pd.read_excel("/content/drive/My Drive/TrabalhoSD/lyrics_dataset.xlsx")

# %%
df_lyrics.head(10)
# Out:
#    Unnamed: 0  ...                          lyric
# 0           0  ...                           Asas
# 1           1  ...          Tudo Que Você Quiser
# 2           2  ...  Mesmo Sem Estar (part. Sandy)
# 3           3  ...     Vingança (part. MC Kekel)
# 4           4  ...    Garotas Não Merecem Chorar
# 5           5  ...             Quando a Bad Bater
# 6           6  ...                   Boa Memória
# 7           7  ...            Amar Não É Pecado
# 8           8  ...                 Chuva de Arroz
# 9           9  ...             Água Com Açúcar
#
# [10 rows x 4 columns]

# %% [markdown]
# Análise de Distribuiçao por Estilo Musical

# %%
    x1 = df_lyrics.loc[df_lyrics['band'] == "luan-santana", 'band']
    x2 = df_lyrics.loc[df_lyrics['band'] == "henrique-e-juliano", 'band']
    x3 = df_lyrics.loc[df_lyrics['band'] == "mc-kevinho", 'band']
    x4 = df_lyrics.loc[df_lyrics['band'] == "mc-maha", 'band']
    x5 = df_lyrics.loc[df_lyrics['band'] == "metallica", 'band']
    x6 = df_lyrics.loc[df_lyrics['band'] == "nirvana", 'band']

    trace1 = go.Histogram(x=x1, name='Sertanejo', opacity=0.75)
    trace2 = go.Histogram(x=x2, name='Sertanejo', opacity=0.75)
    trace3 = go.Histogram(x=x3, name='Funk', opacity=0.75)
    trace4 = go.Histogram(x=x4, name='Funk', opacity=0.75)
    trace5 = go.Histogram(x=x5, name='Rock', opacity=0.75)
    trace6 = go.Histogram(x=x6, name='Rock', opacity=0.75)

    data = [trace1, trace2, trace3, trace4, trace5, trace6]
    layout = go.Layout(barmode='overlay', title='Análise de Distribuição por Estilo Musical')
    fig = go.Figure(data=data, layout=layout)

    iplot(fig, filename='overlaid histogram')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c1102387-6725-48ac-b7f8-55a347e68bcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c1102387-6725-48ac-b7f8-55a347e68bcb")) {
#                     Plotly.newPlot(
#                         'c1102387-6725-48ac-b7f8-55a347e68bcb',
# ...
